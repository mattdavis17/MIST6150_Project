# %% [markdown]
# #### Food Inspection Data Set Description
# "The Health Division of the Department of Inspectional Services ensures that all food establishments in the City of Boston meet relevant sanitary codes and standards. Businesses that serve food are inspected at least once a year, and follow-up inspections are performed on high risk establishments. Health inspections are also conducted in response to complaints of unsanitary conditions or illness."  *(Source - https://data.boston.gov)*
#
# The number of violations is defined as:
#
# 1) *      Minor Violation
#
# 2) **     Major Violation
#
# 3) ***    Severe Violation
#
# *(Source - https://restaurantprediction.weebly.com)*

# %% [markdown]
# #### Data Cleaning Summary
# 1) Convert attributes to appropriate date type and format
#
#     a) licenseno and property_id to object from int and float, respectively
#
#     b) all -dttm columns (5) to datetime
#
#     c) zip to 5-digit format
#
# 2) Filter data by "active" license
#
# 3) Filter data for inspection result ('resultdttm') for dates from 2015 to current (to match df_crime)
#
# 4) Take care of missing values - **TO BE DONE**
#
#     a) there are 21 rows with zip as 00000.  These 21 rows are from Boston, MA and of two business names.  Potentially can fill zip with appropriate zip code
#
#     b) do not necessarily need to delete any other rows.

# %% [markdown]
# #### Current Final Clean Data Set Information
#
# 1) Name = dfins_activefrm15
#
# 2) Shape = 171,293 rows x 26 columns

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
pd.set_option('display.max_columns', None)  # display all columns on screen
import re

# %%
df_ins_org = pd.read_csv(r'C:\Users\ale\Desktop\MIST6150\Project\df_ins.csv')
# Out:
# C:\Users\ale\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (1,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_ins_org.head(3)
# Out:
#                businessname dbaname         legalowner namelast namefirst  \
# 0  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 1  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 2  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
#
#    licenseno              issdttm              expdttm licstatus licensecat  \
# 0      87059  2013-04-05 12:47:23  2019-12-31 23:59:00    Active         FS
# 1      87059  2013-04-05 12:47:23  2019-12-31 23:59:00    Active         FS
# 2      87059  2013-04-05 12:47:23  2019-12-31 23:59:00    Active         FS
#
#             descript   result           resultdttm        violation viollevel  \
# 0  Eating & Drinking  HE_Fail  2013-02-15 12:19:42      15-4-202.16         *
# 1  Eating & Drinking  HE_Fail  2013-02-15 12:19:42  16-4-501.11/.15         *
# 2  Eating & Drinking  HE_Fail  2013-02-15 12:19:42  16-4-501.11/.15         *
#
#                     violdesc             violdttm violstatus statusdate  \
# 0  Non-Food Contact Surfaces  2013-02-15 12:19:42       Fail        NaN
# 1      Dishwashng Facilities  2013-02-15 12:19:42       Fail        NaN
# 2      Dishwashng Facilities  2013-02-15 12:19:42       Fail        NaN
#
#                                             comments              address  \
# 0                        Provide glass storage rack.  635   Hyde Park AVE
# 1  Provide dish rack over 3 bay sink to replace m...  635   Hyde Park AVE
# 2          Provide dish washer at ware washing area.  635   Hyde Park AVE
#
#          city state    zip  property_id                       location
# 0  Roslindale    MA  02131      77476.0  (42.278590000, -71.119440000)
# 1  Roslindale    MA  02131      77476.0  (42.278590000, -71.119440000)
# 2  Roslindale    MA  02131      77476.0  (42.278590000, -71.119440000)

# %%
df_ins_org.shape
# Out:
# (562720, 26)

# %%
df_ins_org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562720 entries, 0 to 562719
# Data columns (total 26 columns):
# businessname    562720 non-null object
# dbaname         5426 non-null object
# legalowner      392419 non-null object
# namelast        562720 non-null object
# namefirst       562606 non-null object
# licenseno       562720 non-null int64
# issdttm         562720 non-null object
# expdttm         562720 non-null object
# licstatus       562720 non-null object
# licensecat      562720 non-null object
# descript        562720 non-null object
# result          562720 non-null object
# resultdttm      562720 non-null object
# violation       530897 non-null object
# viollevel       530897 non-null object
# violdesc        530896 non-null object
# violdttm        562720 non-null object
# violstatus      530897 non-null object
# statusdate      233765 non-null object
# comments        562716 non-null object
# address         562720 non-null object
# city            562694 non-null object
# state           562720 non-null object
# zip             562485 non-null object
# property_id     432886 non-null float64
# location        402155 non-null object
# dtypes: float64(1), int64(1), object(24)
# memory usage: 111.6+ MB

# %%
# copy df_ins_org as df_ins.  
df_ins = df_ins_org.copy()

# %%
# change data type of "issdttm", "expdttm", "resultdttm", "violdttm", and "statusdate" to date/time 
df_ins['issdttm']=pd.to_datetime(df_ins['issdttm'], format='%Y-%m-%d', errors='coerce')
df_ins['expdttm']=pd.to_datetime(df_ins['expdttm'], format='%Y-%m-%d', errors = 'coerce')
df_ins['resultdttm']=pd.to_datetime(df_ins['resultdttm'], format='%Y-%m-%d', errors = 'coerce')
df_ins['violdttm']=pd.to_datetime(df_ins['violdttm'], format='%Y-%m-%d', errors = 'coerce')
df_ins['statusdate']=pd.to_datetime(df_ins['statusdate'], format='%Y-%m-%d', errors = 'coerce')

# %%
# change data type of "licenseno" from integer to object, and "property_id" from float to object
df_ins['licenseno']=df_ins['licenseno'].astype(str)
df_ins['property_id']=df_ins['property_id'].astype(str)

# %%
# change zip to correct 5-digit format
df_ins['zip']=df_ins['zip'].astype(str).str.zfill(5)

# %%
# confirm data type change for df_ins
df_ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562720 entries, 0 to 562719
# Data columns (total 26 columns):
# businessname    562720 non-null object
# dbaname         5426 non-null object
# legalowner      392419 non-null object
# namelast        562720 non-null object
# namefirst       562606 non-null object
# licenseno       562720 non-null object
# issdttm         562607 non-null datetime64[ns]
# expdttm         562449 non-null datetime64[ns]
# licstatus       562720 non-null object
# licensecat      562720 non-null object
# descript        562720 non-null object
# result          562720 non-null object
# resultdttm      556323 non-null datetime64[ns]
# violation       530897 non-null object
# viollevel       530897 non-null object
# violdesc        530896 non-null object
# violdttm        530894 non-null datetime64[ns]
# violstatus      530897 non-null object
# statusdate      233765 non-null datetime64[ns]
# comments        562716 non-null object
# address         562720 non-null object
# city            562694 non-null object
# state           562720 non-null object
# zip             562720 non-null object
# property_id     562720 non-null object
# location        402155 non-null object
# dtypes: datetime64[ns](5), object(21)
# memory usage: 111.6+ MB

# %%
# filter by license status = active
df_ins=df_ins[df_ins['licstatus']=='Active']
df_ins.shape
# Out:
# (355029, 26)

# %%
# filter by license expirate date = 12/31/2019
df_ins=df_ins[df_ins['expdttm']>='2019']
df_ins.shape
# Out:
# (342409, 26)

# %%
# filter by resultdttm=>2015 (to match with df_crime)
df_ins=df_ins[df_ins['resultdttm']>='2015']
df_ins.shape
# Out:
# (164383, 26)

# %%
df_ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164383 entries, 16 to 562719
# Data columns (total 26 columns):
# businessname    164383 non-null object
# dbaname         951 non-null object
# legalowner      108363 non-null object
# namelast        164383 non-null object
# namefirst       164383 non-null object
# licenseno       164383 non-null object
# issdttm         164383 non-null datetime64[ns]
# expdttm         164383 non-null datetime64[ns]
# licstatus       164383 non-null object
# licensecat      164383 non-null object
# descript        164383 non-null object
# result          164383 non-null object
# resultdttm      164383 non-null datetime64[ns]
# violation       158686 non-null object
# viollevel       158686 non-null object
# violdesc        158686 non-null object
# violdttm        158686 non-null datetime64[ns]
# violstatus      158686 non-null object
# statusdate      71483 non-null datetime64[ns]
# comments        164383 non-null object
# address         164383 non-null object
# city            164383 non-null object
# state           164383 non-null object
# zip             164383 non-null object
# property_id     164383 non-null object
# location        121472 non-null object
# dtypes: datetime64[ns](5), object(21)
# memory usage: 33.9+ MB

# %%
df_ins.describe()
# Out:
#          businessname    dbaname legalowner           namelast namefirst  \
# count          164383        951     108363             164383    164383
# unique           3283         17       1482               2783      1437
# top     Dunkin Donuts  1844 Inc.             CVS PHARMACY INC.
# freq              897        177      12227               1052     71191
# first             NaN        NaN        NaN                NaN       NaN
# last              NaN        NaN        NaN                NaN       NaN
#
#        licenseno              issdttm              expdttm licstatus  \
# count     164383               164383               164383    164383
# unique      3631                 3628                    1         1
# top       137896  2015-06-30 08:46:46  2019-12-31 23:59:00    Active
# freq         415                  415               164383    164383
# first        NaN  2011-11-02 14:01:20  2019-12-31 23:59:00       NaN
# last         NaN  2019-03-07 10:40:45  2019-12-31 23:59:00       NaN
#
#        licensecat           descript   result           resultdttm  \
# count      164383             164383   164383               164383
# unique          4                  4       12                34767
# top            FS  Eating & Drinking  HE_Fail  2015-03-04 10:59:57
# freq        83376              83376    71835                   50
# first         NaN                NaN      NaN  2015-01-02 10:07:21
# last          NaN                NaN      NaN  2019-03-08 13:54:29
#
#           violation viollevel                         violdesc  \
# count        158686    158686                           158686
# unique           90         3                               88
# top     23-4-602.13         *  Non-Food Contact Surfaces Clean
# freq          12635    118735                            12635
# first           NaN       NaN                              NaN
# last            NaN       NaN                              NaN
#
#                    violdttm violstatus           statusdate comments  \
# count                158686     158686                71483   164383
# unique                29090          2                 9308    73776
# top     2015-03-20 11:02:51       Fail  2017-06-30 15:24:18
# freq                     50      87204                   57     7114
# first   2007-06-05 14:20:00        NaN  2015-01-02 15:33:37      NaN
# last    2019-03-08 13:54:29        NaN  2019-03-08 15:42:26      NaN
#
#                 address    city   state     zip property_id  \
# count            164383  164383  164383  164383      164383
# unique             2740      45       3      36        2377
# top     1   Citywide ST  Boston      MA   02116         nan
# freq               2139   64733  162408   16089       26074
# first               NaN     NaN     NaN     NaN         NaN
# last                NaN     NaN     NaN     NaN         NaN
#
#                              location
# count                          121472
# unique                           1971
# top     (42.285670000, -71.155480000)
# freq                              576
# first                             NaN
# last                              NaN

# %% [markdown]
# ##Reviewing attributes with finite sets of values

# %%
df_ins['result'].unique()
# Out:
# array(['HE_Fail', 'HE_Pass', 'HE_FailExt', 'HE_Filed', 'HE_Hearing',
#        'HE_NotReq', 'HE_OutBus', 'HE_TSOP', 'HE_Closure', 'HE_Misc',
#        'HE_FAILNOR', 'Pass'], dtype=object)

# %%
df_ins['licensecat'].unique()
# Out:
# array(['FS', 'FT', 'RF', 'MFW'], dtype=object)

# %%
df_ins['descript'].unique()
# Out:
# array(['Eating & Drinking', 'Eating & Drinking w/ Take Out',
#        'Retail Food', 'Mobile Food Walk On'], dtype=object)

# %%
df_ins['violstatus'].unique()
# Out:
# array(['Fail', nan, 'Pass'], dtype=object)

# %%
df_ins.groupby('city')['businessname','zip'].count()
# Out:
#                              businessname    zip
# city
#                                         4      4
# ALLSTON                               938    938
# Allston                              6403   6403
# BOSTON                               9663   9663
# BRIGHTON                              675    675
# Back Bay/                              12     12
# Boston                              64733  64733
# Brighton                             4677   4677
# Brighton/                              26     26
# CHARLESTOWN                           142    142
# CHESTNUT HILL                           8      8
# Charlestown                          1640   1640
# Charlestown/                           22     22
# Chestnut Hill                         124    124
# DORCHESTER                           3312   3312
# Dorchester                          16811  16811
# Downtown/Financial District             1      1
# EAST BOSTON                          1299   1299
# East Boston                          6637   6637
# East Boston/                          176    176
# Fenway                                 12     12
# Fenway/                                32     32
# Financial District                     12     12
# HYDE PARK                             605    605
# Hyde Park                            3006   3006
# JAMAICA PLAIN                         494    494
# Jamaica Plain                        6990   6990
# MATTAPAN                              416    416
# Mattapan                             2672   2672
# Mattapan/                              17     17
# Mission Hill                         2309   2309
# Mission Hill/                         161    161
# ROSLINDALE                            505    505
# ROXBURY                              1063   1063
# Roslindale                           4812   4812
# Roslindale/                            71     71
# Roxbury                             12613  12613
# SOUTH BOSTON                         1197   1197
# South Boston                         4714   4714
# South Boston/                          91     91
# South End                              91     91
# South End/                              4      4
# WEST ROXBURY                          508    508
# West Roxbury                         4680   4680
# West Roxbury//                          5      5

# %%
df_ins['city'] = df_ins['city'].str.replace('/', '')

# %%
df_ins['city'] = df_ins['city'].str.upper()

# %%
df_ins.groupby('city')['businessname','zip'].count()
# Out:
#                             businessname    zip
# city
#                                        4      4
# ALLSTON                             7341   7341
# BACK BAY                              12     12
# BOSTON                             74396  74396
# BRIGHTON                            5378   5378
# CHARLESTOWN                         1804   1804
# CHESTNUT HILL                        132    132
# DORCHESTER                         20123  20123
# DOWNTOWNFINANCIAL DISTRICT             1      1
# EAST BOSTON                         8112   8112
# FENWAY                                44     44
# FINANCIAL DISTRICT                    12     12
# HYDE PARK                           3611   3611
# JAMAICA PLAIN                       7484   7484
# MATTAPAN                            3105   3105
# MISSION HILL                        2470   2470
# ROSLINDALE                          5388   5388
# ROXBURY                            13676  13676
# SOUTH BOSTON                        6002   6002
# SOUTH END                             95     95
# WEST ROXBURY                        5193   5193

# %%
# dropping un-needed columns
cols_to_drop=['dbaname','legalowner','namelast','namefirst','descript','state']
df_ins=df_ins.drop(cols_to_drop,axis=1)
df_ins.shape
# Out:
# (164383, 20)

# %%
# check for null data
df_ins.isnull().sum()
# Out:
# businessname        0
# licenseno           0
# issdttm             0
# expdttm             0
# licstatus           0
# licensecat          0
# result              0
# resultdttm          0
# violation        5697
# viollevel        5697
# violdesc         5697
# violdttm         5697
# violstatus       5697
# statusdate      92900
# comments            0
# address             0
# city                0
# zip                 0
# property_id         0
# location        42911
# dtype: int64

# %%
# entries with zip = 0000
df_ins[df_ins['zip']<'02108']
# Out:
#                             businessname licenseno             issdttm  \
# 203955  Frog Pond Boston @ Boston Common     75274 2012-02-24 14:04:35
# 203956  Frog Pond Boston @ Boston Common     75274 2012-02-24 14:04:35
# 203969  Frog Pond Boston @ Boston Common     75274 2012-02-24 14:04:35
# 203970  Frog Pond Boston @ Boston Common     75274 2012-02-24 14:04:35
# 280679                    LEGAL SEA FOOD     25105 2012-01-11 07:50:32
# 
# 280697      14-4-202.11         *     Food Contact Surfaces Design
# 280698      17-4-302.14         *                Test Kit Provided
# 280699  27-5-103.11-.12       ***               Hot and Cold Water
# 280700   29-5-201/02.11         *         Installed and Maintained
# 280701  36-6-501.11-.12         *   Improper Maintenance of Floors
# 280702       M-2-103.11       ***            PIC Performing Duties
#
#                   violdttm violstatus          statusdate  \
# 203955 2015-06-30 11:39:06       Fail                 NaT
# 203956 2018-06-29 10:17:36       Fail                 NaT
# 203969                 NaT        NaN                 NaT
# 203970                 NaT        NaN                 NaT
# 280679                 NaT        NaN                 NaT
# 280680 2018-06-07 08:40:39       Fail                 NaT
# 280681 2018-06-07 08:40:39       Fail                 NaT
# 280682 2018-06-07 08:40:39       Fail                 NaT
# 280683 2018-06-07 08:40:39       Fail                 NaT
# 280684 2018-06-07 08:40:39       Fail                 NaT
# 280685 2018-06-07 08:40:39       Fail                 NaT
# 280686 2018-06-07 08:40:39       Fail                 NaT
# 280694                 NaT        NaN                 NaT
# 280695                 NaT        NaN                 NaT
# 280696 2018-06-18 08:43:35       Pass 2018-06-18 09:14:58
# 280697 2018-06-18 08:43:35       Pass 2018-06-18 09:14:58
# 280698 2018-06-18 08:43:35       Pass 2018-06-18 09:14:58
# 280699 2018-06-18 08:43:35       Pass 2018-06-18 09:14:58
# 280700 2018-06-18 08:43:35       Pass 2018-06-18 09:14:58
# 280701 2018-06-18 08:43:35       Pass 2018-06-18 09:14:58
# 280702 2018-06-18 08:43:35       Pass 2018-06-18 09:14:58
#
#                                                  comments         address  \
# 203955  clean drain compartments to fryers. Clean inte...
# 203956  Clean to remove ice build up from dippin dots ...
# 203969
# 203970
# 280679                                                         CITYWIDE
# 280680                 provide accurate cooks thermometer      CITYWIDE
# 280681                     provide extra serving utensils      CITYWIDE
# 280682                            provide proper test kit      CITYWIDE
# 280683  repair handsink to provide hot and cold water ...      CITYWIDE
# 280684                  repair leak from under steamtable      CITYWIDE
# 280685                   clean floor area to remove soils      CITYWIDE
# 280686  post allergen and certified food managers cert...      CITYWIDE
# 280694                                                         CITYWIDE
# 280695                                                         CITYWIDE
# 280696                 provide accurate cooks thermometer      CITYWIDE
# 280697                     provide extra serving utensils      CITYWIDE
# 280698                            provide proper test kit      CITYWIDE
# 280699  repair handsink to provide hot and cold water ...      CITYWIDE
# 280700                  repair leak from under steamtable      CITYWIDE
# 280701                   clean floor area to remove soils      CITYWIDE
# 280702  post allergen and certified food managers cert...      CITYWIDE
#
#           city    zip property_id location
# 203955          0000          nan      NaN
# 203956          0000          nan      NaN
# 203969          0000          nan      NaN
# 203970          0000          nan      NaN
# 280679  BOSTON  0000          nan      NaN
# 280680  BOSTON  0000          nan      NaN
# 280681  BOSTON  0000          nan      NaN
# 280682  BOSTON  0000          nan      NaN
# 280683  BOSTON  0000          nan      NaN
# 280684  BOSTON  0000          nan      NaN
# 280685  BOSTON  0000          nan      NaN
# 280686  BOSTON  0000          nan      NaN
# 280694  BOSTON  0000          nan      NaN
# 280695  BOSTON  0000          nan      NaN
# 280696  BOSTON  0000          nan      NaN
# 280697  BOSTON  0000          nan      NaN
# *                118735     118735   118735   118735     118735      118735
# **                10191      10191    10191    10191      10191       10191
# ***               29760      29760    29760    29760      29760       29760
#
#            result  resultdttm  violation  violdesc  violdttm  violstatus  \
# viollevel
# *          118735      118735     118735    118735    118735      118735
# **          10191       10191      10191     10191     10191       10191
# ***         29760       29760      29760     29760     29760       29760
#
#            statusdate  comments  address    city     zip  property_id  \
# viollevel
# *               52138    118735   118735  118735  118735       118735
# **               4920     10191    10191   10191   10191        10191
# ***             14425     29760    29760   29760   29760        29760
#
#            location
# viollevel
# *             88626
# **             7691
# ***           21780

# %%
df_ins.head()
# Out:
#                 businessname licenseno             issdttm  \
# 16  100 Percent Delicia Food     87059 2013-04-05 12:47:23
# 17  100 Percent Delicia Food     87059 2013-04-05 12:47:23
# 18  100 Percent Delicia Food     87059 2013-04-05 12:47:23
# 19  100 Percent Delicia Food     87059 2013-04-05 12:47:23
# 20         Ariana Restaurant    136868 2015-08-24 11:29:01
#
#                expdttm licstatus licensecat   result          resultdttm  \
# 16 2019-12-31 23:59:00    Active         FS  HE_Fail 2015-07-27 14:22:38
# 17 2019-12-31 23:59:00    Active         FS  HE_Fail 2015-07-27 14:22:38
# 18 2019-12-31 23:59:00    Active         FS  HE_Fail 2015-07-27 14:22:38
# 19 2019-12-31 23:59:00    Active         FS  HE_Fail 2015-07-27 14:22:38
# 20 2019-12-31 23:59:00    Active         FS  HE_Pass 2017-10-17 19:37:12
#
#                violation viollevel  \
# 16  08-3-302.11/3-304.11       ***
# 17       08-3-305-307.11         *
# 18       08-3-305-307.11         *
# 19     17-4-204.112/.115         *
# 20                   NaN       NaN
#
#                                        violdesc            violdttm  \
# 16  Separation  Segregation Cross Contamination 2015-07-27 14:22:38
# 17                              Food Protection 2015-07-27 14:22:38
# 18                              Food Protection 2015-07-27 14:22:38
# 19                       Equipment Thermometers 2015-07-27 14:22:38
# 20                                          NaN                 NaT
#
#    violstatus statusdate                                           comments  \
# 16       Fail        NaT  Observed raw chicken stored over ready to eat ...
# 17       Fail        NaT  Closet next to microwave with pots stored on t...
# 18       Fail        NaT  Observed buckets of food products stored direc...
# 19       Fail        NaT  Provide working internal thermometers for all ...
# 20        NaN        NaT
#
#                 address        city    zip property_id  \
# 16  635   Hyde Park AVE  ROSLINDALE  02131     77476.0
# 17  635   Hyde Park AVE  ROSLINDALE  02131     77476.0
# 18  635   Hyde Park AVE  ROSLINDALE  02131     77476.0
# 19  635   Hyde Park AVE  ROSLINDALE  02131     77476.0
# 20     123   Antwerp ST    BRIGHTON  02135    343305.0
#
#                          location
# 16  (42.278590000, -71.119440000)
# 17  (42.278590000, -71.119440000)
# 18  (42.278590000, -71.119440000)
# 19  (42.278590000, -71.119440000)
# 20                            NaN

# %%
df_ins.violstatus.unique()
# Out:
# array(['Fail', nan, 'Pass'], dtype=object)

# %%
df_ins.groupby('viollevel').value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-af976aa3f5d0> in <module>
# ----> 1 df_ins.groupby('viollevel').value_counts(dropna=False)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
# --> 765                              (type(self).__name__, attr))
#     766
#     767     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'
